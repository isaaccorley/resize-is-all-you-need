# %%
# Clean metrics
import os
import json
import pandas as pd

directory = "bigearthnet"
with open(os.path.join(directory, "bigearthnet-results.json")) as f:
    results = json.load(f)

df = pd.DataFrame.from_dict(results).transpose()
df["rgb"] = ["RGB" if "rgb" in model_name else "MSI" for model_name in df.index]
df["size"] = [int(model_name.split("_")[-1]) for model_name in df.index]
df["encoder"] = [
    model_name.rsplit("_", 1)[0].replace("_rgb", "") for model_name in df.index
]
df = df.sort_values(["rgb", "encoder", "size"], ascending=True)
df.to_csv(os.path.join(directory, "bigearthnet-results.csv"))
df
# Out:
#                                       f1_weighted  f1_macro  f1_micro  \
# imagestats_120                           0.651082  0.537867  0.659509
# resnet50_pretrained_imagenet_120         0.528594  0.392639  0.548482
# resnet50_pretrained_imagenet_224         0.524147  0.392581  0.542651
# resnet50_pretrained_moco_120             0.623559  0.510368  0.636008
# resnet50_pretrained_moco_224             0.674735  0.574276  0.683246
# imagestats_rgb_120                       0.563085  0.434009  0.576377
# resnet50_pretrained_imagenet_rgb_120     0.491319  0.383967  0.504616
# resnet50_pretrained_moco_rgb_120         0.683362  0.591618  0.689869
# resnet50_pretrained_moco_rgb_224         0.720809  0.642007  0.725450
#
#                                       precision_micro  precision_macro  \
# imagestats_120                               0.704769         0.643811
# resnet50_pretrained_imagenet_120             0.623239         0.575213
# resnet50_pretrained_imagenet_224             0.615155         0.563378
# resnet50_pretrained_moco_120                 0.705660         0.663104
# resnet50_pretrained_moco_224                 0.739566         0.702708
# imagestats_rgb_120                           0.640903         0.570860
# resnet50_pretrained_imagenet_rgb_120         0.588856         0.528512
# resnet50_pretrained_moco_rgb_120             0.742560         0.697279
# resnet50_pretrained_moco_rgb_224             0.770140         0.730220
#
#                                       precision_weighted  recall_micro  \
# imagestats_120                                  0.696353      0.619711
# resnet50_pretrained_imagenet_120                0.606899      0.489739
# resnet50_pretrained_imagenet_224                0.601616      0.485437
# resnet50_pretrained_moco_120                    0.696508      0.578870
# resnet50_pretrained_moco_224                    0.734428      0.634898
# imagestats_rgb_120                              0.626084      0.523655
# resnet50_pretrained_imagenet_rgb_120            0.574601      0.441462
# resnet50_pretrained_moco_rgb_120                0.737953      0.644161
# resnet50_pretrained_moco_rgb_224                0.766259      0.685662
#
#                                       recall_macro  recall_weighted  accuracy  \
# imagestats_120                            0.489935         0.619711  0.258132
# resnet50_pretrained_imagenet_120          0.340866         0.489739  0.201429
# resnet50_pretrained_imagenet_224          0.340252         0.485437  0.197257
# resnet50_pretrained_moco_120              0.447545         0.578870  0.246476
# resnet50_pretrained_moco_224              0.511070         0.634898  0.272838
# imagestats_rgb_120                        0.381247         0.523655  0.212011
# resnet50_pretrained_imagenet_rgb_120      0.327819         0.441462  0.177657
# resnet50_pretrained_moco_rgb_120          0.534111         0.644161  0.277112
# resnet50_pretrained_moco_rgb_224          0.588812         0.685662  0.303434
#
#                                       rgb  size                       encoder
# imagestats_120                        MSI   120                    imagestats
# resnet50_pretrained_imagenet_120      MSI   120  resnet50_pretrained_imagenet
# resnet50_pretrained_imagenet_224      MSI   224  resnet50_pretrained_imagenet
# resnet50_pretrained_moco_120          MSI   120      resnet50_pretrained_moco
# resnet50_pretrained_moco_224          MSI   224      resnet50_pretrained_moco
# imagestats_rgb_120                    RGB   120                    imagestats
# resnet50_pretrained_imagenet_rgb_120  RGB   120  resnet50_pretrained_imagenet
# resnet50_pretrained_moco_rgb_120      RGB   120      resnet50_pretrained_moco
# resnet50_pretrained_moco_rgb_224      RGB   224      resnet50_pretrained_moco
